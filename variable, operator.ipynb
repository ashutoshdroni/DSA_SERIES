# %%
print("hello world")
# Out:
# hello world

# %%
print("ashutosh")
# Out:
# ashutosh

# %% [markdown]
# ## number

# %%
a1 = 23
a2 = 3.4
a3 = 4 + 5j

print(a1)

print(type(a1))

print(a2)

print(type(a2))

print(a3)

print(type(a3))
# Out:
# 23
# <class 'int'>
# 3.4
# <class 'float'>
# (4+5j)
# <class 'complex'>

# %% [markdown]
# ## id command

# %%
a1 = 23
print(id(a1))
a2 = 3
print(id(a2))
# Out:
# 140711251164280
# 140711251163640

# %% [markdown]
# ##  variable

# %%
a = 10
b = 20
sum = a + b
print(sum)   #it print value of sum
# Out:
# 30

# %%
a = 10
b = 20
sum = a + b
print("sum")  #it print sum as a string
# Out:
# sum

# %% [markdown]
# ## arithmetic operator

# %%
a = 10
b = 20
sum = a + b
print(sum)
# Out:
# 30

# %%
a = 100
b = 20
sub = a - b
print(sub)
# Out:
# 80

# %%
a = 10
b = 20
mup = a * b
print(mup)
# Out:
# 200

# %%
a = 101
b = 20
div = a / b
print(div) #floating point divison
# Out:
# 5.05

# %%
a = 101
b = 20
div = a // b
print(div) #integer divison
# Out:
# 5

# %%
a = 103
b = 20
div = a % b
print(div) #modulo
# Out:
# 3

# %% [markdown]
# ## simple intrest

# %%
p = 500
r = 2
t = 12
pi = (p*r*t)//100
print(pi)
# Out:
# 120

# %% [markdown]
# ## fah to celcius converter

# %%
f = 100
c = (f-32)*5/9
print(c)
# Out:
# 37.77777777777778

# %% [markdown]
# ## find average marks

# %%
a = 3
b = 4
c = 6
sum = a+b+c
avg = sum/3
avg
# Out:
# 4.333333333333333

# %% [markdown]
# # taking input

# %%
n = input()
n
# Out:
#  ashutosh
# 'ashutosh'

# %%
n = input()
m = input()
sum = (n + m)
print(sum) #it print the result in the form of string bcz input always give value in the form of string
# Out:
#  55
#  88
# 5588

# %% [markdown]
# ## add two number

# %%
n = int(input())
m = int(input())
sum = (n + m)
print(sum) # for find integer value use int
# Out:
#  80
#  90
# 170

# %%
n = float(input())
m = float(input())
sum = (n + m)
print(sum)
# Out:
#  77
#  99
# 176.0

# %% [markdown]
# ## Boolean

# %%
a = True
b = False
c = True
print(type(b))
print(type(a))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ## relational operator

# %%
a = 10
b = 20
print (a > b)
print (a < b)
print (a <= b)
print (a >= b)
print (a == b)
print (a != b)
# Out:
# False
# True
# True
# False
# False
# True

# %% [markdown]
# ## logical operator

# %%
a=10
b=20
c1 = a>10
c2 = b>10
r1 = c1 and c2
r2 = c1 or c2
r3 = not(c1)
print(r1)
print(r2)
print(r3)
# Out:
# False
# True
# True
