# %%
#TUPLE ARE USED TO STORE MULTIPLE ITEMS IN A SINGLE VARIABLE(IMMUTABLE)
a = (1,2)
print(a)
# Out:
# (1, 2)

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
b,c =(5,6)
print(b)
print(c)
e = 8,9
print(e)
print(type(e))
# Out:
# 5
# 6
# (8, 9)
# <class 'tuple'>

# %%
print(e[0])
# Out:
# 8

# %%
print(e[1])
# Out:
# 9

# %%
print(e[-1])
# Out:
# 9

# %%
print(e[-2])
# Out:
# 8

# %%
#slicing
f =(1,2,3,4,5,6,7)
print(f[3:])
# Out:
# (4, 5, 6, 7)

# %%
a = 1,2,3
b = 4,5
for i in a:
    print(i)
# Out:
# 1
# 2
# 3

# %%
print(1 in a)
# Out:
# True

# %%
print(1 in b)
# Out:
# False

# %%
print(len(a))
# Out:
# 3

# %%
print(len(b))
# Out:
# 2

# %%
#concetation
c = a+b
print(c)
# Out:
# (1, 2, 3, 4, 5)

# %%
d = (a,b)
print(d)
# Out:
# ((1, 2, 3), (4, 5))

# %%
print(min(a))
# Out:
# 1

# %%
print(max(a and b))
# Out:
# 5

# %%
e = a*4
print(e)
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
#list to tuple
l=[1,2,3,4]
print(tuple(l))
# Out:
# (1, 2, 3, 4)

# %%
#variable length input and output
def sum (a,b,c=0,d=0,e=0):
    return a+b+c+d+e
print(sum(1,2,3,4,5))
# Out:
# 15

# %%
#variable length input and output
def sum (a,b,c=0,d=0,e=3):
    return a+b+c+d+e
print(sum(1,2,3,4))
# Out:
# 13

# %%
def sum1 (a,b,*more):
    print(a)
    print(b)
    print(more)
sum1(2,3,4,5)
# Out:
# 2
# 3
# (4, 5)

# %%
def sum_diff(a,b):
    return a+b,a-b
c= sum_diff(4,1)
print(c)
# Out:
# (5, 3)

# %%
d,e =  sum_diff(4,1)
print(d)
print(e)
# Out:
# 5
# 3
