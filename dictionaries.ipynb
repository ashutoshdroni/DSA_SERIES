# %%
a ={}
type(a)
# Out:
# dict

# %%
a = {"the":1,"a":5,10000:"abc"}
type(a)
# Out:
# dict

# %%
a
# Out:
# {'the': 1, 'a': 5, 10000: 'abc'}

# %%
len(a)
# Out:
# 3

# %%
#another way to creating dictionaries
b= a.copy()
b
# Out:
# {'the': 1, 'a': 5, 10000: 'abc'}

# %%
#another way
c = dict([("the",3),("a",10),(2,3)])
c
# Out:
# {'the': 3, 'a': 10, 2: 3}

# %%
#another way
d=dict.fromkeys(["abc",32,4])
d
#when we provide value it print value otherwise ir print none
# Out:
# {'abc': None, 32: None, 4: None}

# %%
d=dict.fromkeys(["abc",32,4],10)
d
# Out:
# {'abc': 10, 32: 10, 4: 10}

# %%
#dummy dictionaries
a ={1:2,3:4,"list":[1,23],"dict":{1:23}}
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 23}}

# %%
a['list']
# Out:
# [1, 23]

# %%
a.get('list')
# Out:
# [1, 23]

# %%
a[1]
# Out:
# 2

# %%
a[3]
# Out:
# 4

# %%
print(a.get("li"))
# Out:
# None

# %%
print(a.get("li",2))
# Out:
# 2

# %%
a.keys()
# Out:
# dict_keys([1, 3, 'list', 'dict'])

# %%
a.values()
# Out:
# dict_values([2, 4, [1, 23], {1: 23}])

# %%
a.items()
# Out:
# dict_items([(1, 2), (3, 4), ('list', [1, 23]), ('dict', {1: 23})])

# %%
for i in a:
    print(i)
# Out:
# 1
# 3
# list
# dict

# %%
for i in a :
    print(i,a[i])
# Out:
# 1 2
# 3 4
# list [1, 23]
# dict {1: 23}

# %%
for i in a.values() :
    print(i)
# Out:
# 2
# 4
# [1, 23]
# {1: 23}

# %%
"list" in a
# Out:
# True

# %%
2 in a
#it check only key not value
# Out:
# False

# %%
#adding data in dictionaries
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 23}}

# %%
a['t']=(1,2,3)
a
# Out:
# {1: 2, 3: 4, 'list': [1, 23], 'dict': {1: 23}, 't': (1, 2, 3)}

# %%
a[1]=10
a
# Out:
# {1: 10, 3: 4, 'list': [1, 23], 'dict': {1: 23}, 't': (1, 2, 3)}

# %%
#update data
b={3:5,'the':4,2:100}
a.update(b)
a
# Out:
# {1: 10,
#  3: 5,
#  'list': [1, 23],
#  'dict': {1: 23},
#  't': (1, 2, 3),
#  'the': 4,
#  2: 100}

# %%
#remove data 
a.pop('t')
# Out:
# (1, 2, 3)

# %%
a
# Out:
# {1: 10, 3: 5, 'list': [1, 23], 'dict': {1: 23}, 'the': 4, 2: 100}

# %%
del a[1]
a
# Out:
# {3: 5, 'list': [1, 23], 'dict': {1: 23}, 'the': 4, 2: 100}

# %%
a.clear()
a
# Out:
# {}
